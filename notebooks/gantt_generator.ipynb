# %%
import pandas as pd
import matplotlib.pyplot as plt
from gantt import create_gantt_chart

# %%
df = pd.read_csv('../data/tasks.csv')
print("📋 Задачи:")
print(df)
# Out:
# 📋 Задачи:
#    Task Dependencies  Duration  Workers
# 0     A          NaN         3        1
# 1     B            A        11        2
# 2     C            A         4        0
# 3     D            C         7        4
# 4     E            B         3        9
# 5     F            C        10        5
# 6     G          D,E         3        3
# 7     H          F,G         6        6
# 8     I          D,E         4        8
# 9     J          NaN         9        3
# 10    K        H,I,J         5        3
# 11    L          F,G         9        2
# 12    M          K,L         4        1
# 13    N            M         7        3
# 14    O        H,I,J         8        3

# %%
result = create_gantt_chart(df, save_path='../figs/gantt_chart.png')
# Out:
# ...
# 🔍 АВТОМАТИЧЕСКИЙ АНАЛИЗ СТРУКТУРЫ ПРОЕКТА
# ...
# 🎯 УМНОЕ ОПРЕДЕЛЕНИЕ СТРУКТУРЫ ПРОЕКТА...
#    📝 Колонка задач: 'Task'
# 🔍 АНАЛИЗ ЛОГИЧЕСКОЙ СТРУКТУРЫ ПРОЕКТА...
# ✅ Обнаружены зависимости: None
# ✅ СТРУКТУРА ПРОЕКТА ОПРЕДЕЛЕНА:
#    • TASK: 'Task'
#    • DURATION: 'Duration'
#    • WORKERS: 'Workers'
#    • DEPENDENCIES: 'Dependencies'
# 🔍 ВАЛИДАЦИЯ ДАННЫХ...
# ...
# ✅ ВАЛИДАЦИЯ ПРОЙДЕНА УСПЕШНО!
#    • Задачи: 15
#    • Колонки: Task, Dependencies, Duration, Workers, Start
#    • Период: 24.10.2025 - N/A
# 🔄 РАСЧЕТ КРИТИЧЕСКОГО ПУТИ И ДАТ...
# ✅ Критический путь: 8 задач
# 🔗 Цепочка: A → B → E → G → H → K → M → N
# 🎨 ПОСТРОЕНИЕ ДИАГРАММЫ...
# 💾 Диаграмма сохранена: ../figs/gantt_chart.png
# ...
# 📊 АНАЛИЗ ПРОЕКТА
# ...
# Всего задач: 15
# Критических задач: 8
# Общая длительность: 42 дней
# Период: 24.10.2025 - 05.12.2025
#
# 🔴 КРИТИЧЕСКИЕ ЗАДАЧИ:
#    • A - 3 дней [1ч]
#    • B - 11 дней [2ч] ← A
#    • E - 3 дней [9ч] ← B
#    • G - 3 дней [3ч] ← D,E
#    • H - 6 дней [6ч] ← F,G
# ...
