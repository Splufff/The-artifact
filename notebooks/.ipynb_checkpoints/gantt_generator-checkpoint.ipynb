# %%
import pandas as pd
import matplotlib.pyplot as plt
from gantt import create_gantt_chart

# %%
df = pd.read_csv('../data/tasks.csv')
print("📋 Задачи:")
print(df)
# Out:
# 📋 Задачи:
#    Task Dependencies  Duration  Workers
# 0     A          NaN         3        1
# 1     B            A        11        2
# 2     C            A         4        0
# 3     D            C         7        4
# 4     E            B         3        9
# 5     F            C        10        5
# 6     G          D,E         3        3
# 7     H          F,G         6        6
# 8     I          D,E         4        8
# 9     J          NaN         9        3
# 10    K        H,I,J         5        3
# 11    L          F,G         9        2
# 12    M          K,L         4        1
# 13    N            M         7        3
# 14    O        H,I,J         8        3

# %%
result = create_gantt_chart(df, save_path='../figs/gantt_chart.png')
# Out:
# ============================================================
# 🔍 АВТОМАТИЧЕСКИЙ АНАЛИЗ СТРУКТУРЫ ПРОЕКТА
# ============================================================
# 🎯 УМНОЕ ОПРЕДЕЛЕНИЕ СТРУКТУРЫ ПРОЕКТА...
#    📝 Колонка задач: 'Task'
# 🔍 АНАЛИЗ ЛОГИЧЕСКОЙ СТРУКТУРЫ ПРОЕКТА...
#    📅 Обнаружены временные зависимости
# ✅ Обнаружены зависимости: _temporal_dependencies
# ✅ СТРУКТУРА ПРОЕКТА ОПРЕДЕЛЕНА:
#    • TASK: 'Task'
#    • DURATION: 'Duration'
#    • WORKERS: 'Workers'
# ⚠️  ПРЕДУПРЕЖДЕНИЯ:
#    • Обнаружены пересечения в расписании: 105 конфликтов
# ✅ ВАЛИДАЦИЯ ПРОЙДЕНА УСПЕШНО!
# 🔄 РАСЧЕТ КРИТИЧЕСКОГО ПУТИ И ДАТ...
# ✅ Автоматически исправлены пересечения дат на основе зависимостей
# ✅ Критический путь: 1 задач
# 🔗 Цепочка: B
# 🎨 ПОСТРОЕНИЕ ДИАГРАММЫ...
# 💾 Диаграмма сохранена: ../figs/gantt_chart.png
# ==================================================
# 📊 АНАЛИЗ ПРОЕКТА
# ==================================================
# Всего задач: 15
# Критических задач: 1
# Общая длительность: 11 дней
# Период: 15.10.2025 - 26.10.2025
#
# 🔴 КРИТИЧЕСКИЕ ЗАДАЧИ:
#    • B - 11 дней [2ч]
